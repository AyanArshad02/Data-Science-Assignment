# %%
"""
Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
Matplotlib.
"""
# Matplotlib is a library for creating animated and interactive visualizations in terms of charts and graphs in python.
# Five plots that can be plotted usign pyplot module is:
# scatter
# bar
# hist
# pie
# stem

# %%
"""
Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
plot a scatter plot."""
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
"Note: Also add title, xlabel, and ylabel to the plot."

import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Scatter plot")
plt.show()

# %%
"""
Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
Use the following data:"""
import numpy as np
# For line 1:
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([0, 100, 200, 300, 400, 500])

plt.subplot(4,1,1)
plt.plot(x,y,c="y")

# For line 2:
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([50, 20, 40, 20, 60, 70])

plt.subplot(4,1,2)
plt.plot(x,y,c="r")

# For line 3:
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([10, 20, 30, 40, 50, 60])

plt.subplot(4,1,3)
plt.plot(x,y,c="Brown")

# For line 4:
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([200, 350, 250, 550, 450, 150])

plt.subplot(4,1,4)
plt.plot(x,y,c="blue")

# %%
"Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot."
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

import matplotlib.pyplot as plt
plt.bar(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %%
"Q5: What is a box plot? Why is it used? Using the following data plot a box plot."
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# boxplot mainly provides a graphical summary of a data set with features such as minimum, first quartile, median, third quartile, and maximum
import matplotlib.pyplot as plt
plt.boxplot(box1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f9758c6de10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f9758c6e350>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f9758c6db70>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f9758c6e890>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f9758c6eb30>],
#  'means': []}
